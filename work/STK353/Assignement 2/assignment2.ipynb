# %%
# Initialize Otter
import otter
grader = otter.Notebook("assignment2.ipynb")

# %% [markdown]
# # STK353 Assignemnt 1
#
# ## Instructions:
#
#    - Complete all questions
#    - remember to restart your kernel and run all cells before submitting.
#    - Submit only the `ipynb` file | No need to rename it.
#    - Your data folder should be in a folder called data next to your script.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 1 (a)**: Read Total profit of all months and show it using a line plot
# Total profit data provided for each month. Generated line plot must include the following properties:
#
# - X label name = Month Number
# - Y label name = Total profit
# The line plot graph should look like this.
#
# ![](img/line.png)
#
# <!--
# BEGIN QUESTION
# manual: true
# name: q1a
# -->

# %%
df = pd.read_csv("data/company_sales_data.csv")
x = df['month_number']
y = df['total_profit']
plt.plot(x,y)
plt.xlabel("Month number")
plt.ylabel("Total profit")
plt.title("Company profit per month")
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **Question 1 (b)**: Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
#
# ![](img/lines.png)
#
#
# <!--
# BEGIN QUESTION
# manual: true
# name: q1b
# -->

# %%
facecream = df['facecream']
facewash = df['facewash']
toothpaste = df['toothpaste']
bathingsoap = df['bathingsoap']
shampoo = df['shampoo']
moisturizer = df['moisturizer']
plt.plot(x,facecream,marker='o',label='Face cream Sales Data')
plt.plot(x,facewash,marker='o',label='Face wash Sales Data')
plt.plot(x,toothpaste,marker='o',label='ToothPaste Sales Data')
plt.plot(x,bathingsoap,marker='o',label='BathingSoap Sales Data')
plt.plot(x,shampoo,marker='o',label='Shampoo Sales Data')
plt.plot(x,moisturizer,marker='o',label='Moisturizer Sales Data')
plt.legend()
plt.xlabel("Month Number")
plt.ylabel("Sales units in numbers")
plt.title("Sales data")
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# Import the `chipotle.tsv` and work out the following questions.
#
# **Question 2 (a):** Select only the products with quantity equals to 1 and assign this new dataframe to `chipo_one_prod`
#
#
# <!--
# BEGIN QUESTION
# name: q2_a
# points: 2
# -->

# %%
chipo = pd.read_csv('data/chipotle.tsv', sep = '\t')
chipo_one_prod = pd.DataFrame(chipo.query('quantity==1'))
chipo_one_prod
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4355 rows x 5 columns]

# %%
grader.check("q2_a")
# Out:
# q2_a results: All test cases passed!

# %% [markdown]
# **Question 2 (b):** Delete the duplicates in item_name and quantity and re-assign this new dataframe back to `chipo_filtered`
#
# <!--
# BEGIN QUESTION
# name: q2b
# points: 3
# -->

# %%
chipo_filtered = pd.DataFrame(chipo.drop_duplicates(subset=['item_name','quantity']))
chipo_filtered
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 3890      1559         2                  Carnitas Crispy Tacos
# 3973      1592         4                      Canned Soft Drink
# 4152      1660        10                          Bottled Water
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 3890     [Fresh Tomato Salsa (Mild), [Cheese, Lettuce]]    $17.98
# 3973                                             [Coke]     $5.00
# 4152                                                NaN    $15.00
# 4354            [Fresh Tomato Salsa, [Cheese, Lettuce]]    $18.50
# 4489                                                NaN    $17.80
#
# [103 rows x 5 columns]

# %%
grader.check("q2b")
# Out:
# q2b results: All test cases passed!

# %% [markdown]
# **Question 3:** Create a DataFrame mirroring the table below and assign this to `data`. Then group by the `flavor` column and find the mean price for each flavor; assign this **series** to `price_by_flavor`.
#
# | flavor | scoops | price |
# |-----|-----|-----|
# | chocolate | 1 | 2 |
# | vanilla | 1 | 1.5 |
# | chocolate | 2 | 3 |
# | strawberry | 1 | 2 |
# | strawberry | 3 | 4 |
# | vanilla | 2 | 2 |
# | mint | 1 | 4 |
# | mint | 2 | 5 |
# | chocolate | 3 | 5 |
#
#
#
# <!--
# BEGIN QUESTION
# name: q3
# points:
#     each: 1
# -->

# %%
data = pd.DataFrame({'flavor':['chocolate','vanilla','chocolate','strawberry','strawberry','vanilla','mint','mint','chocolate'],
                     'scoops':[1,1,2,1,3,2,1,2,3],'price':[2,1.5,3,2,4,2,4,5,5]})
price_by_flavor = data.groupby('flavor')['price'].mean()
price_by_flavor
# Out:
# flavor
# chocolate     3.333333
# mint          4.500000
# strawberry    3.000000
# vanilla       1.750000
# Name: price, dtype: float64

# %%
grader.check("q3")
# Out:
# q3 results: All test cases passed!

# %% [markdown]
# **Question 4**: Import the `drinks.csv` dataset and answer the following questions

# %%
drinks = pd.read_csv('data/drinks.csv')
drinks.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF
# 5                           4.9       NaN
# 6                           8.3        SA
# 7                           3.8        EU
# 8                          10.4        OC
# 9                           9.7        EU

# %% [markdown]
# **Question 4 (a):** Compute the mean beer servings per continent ? [type: pd.Series]
#
#
# <!--
# BEGIN QUESTION
# name: q4a
# points: 2
# -->

# %%
q4a = pd.Series(drinks.groupby('continent')['beer_servings'].mean())
q4a
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
grader.check("q4a")
# Out:
# q4a results: All test cases passed!

# %% [markdown]
# **Question 4 (b):** Calculate the mean alcohol consumption per continent for every columnm  [type: pd.DataFrame]
#
# <!--
# BEGIN QUESTION
# name: q4b
# points: 4
# -->

# %%
q4b = pd.DataFrame(drinks.groupby('continent').mean())
q4b
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
grader.check("q4b")
# Out:
# q4b results: All test cases passed!

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
# Out:
# q2_a results: All test cases passed!
#
# q2b results: All test cases passed!
#
# q3 results: All test cases passed!
#
# q4a results: All test cases passed!
#
# q4b results: All test cases passed!
